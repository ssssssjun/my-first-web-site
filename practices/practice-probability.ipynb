# %% [markdown]
# <a href="https://colab.research.google.com/github/ssssssjun/my-first-web-site/blob/main/practices/practice-probability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # (연습) 확률 분포

# %% [markdown]
# **기본 설정**

# %% [markdown]
# Numpy와 Pandas 라이브러리를 각각 np와 pd로 불러온다.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 데이터프레임의 [chained indexing을 금지시키기 위한 설정](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy)을 지정한다.
# Pandas 3.0 버전부터는 기본 옵션으로 지정된다.

# %%
pd.options.mode.copy_on_write = True

# %% [markdown]
# 주피터 노트북에서 부동소수점의 출력을 소수점 이하 6자리로 제한한다.
# 아래 코드는 주피터 노트북에서만 사용하며 일반적인 파이썬 코드가 아니다.

# %%
# %precision 6
# Out:
# '%.6f'

# %% [markdown]
# 아래 코드는 데이터프레임 내에서 부동소수점의 출력을 소수점 이하 6자리로 제한한다.

# %%
pd.set_option('display.precision', 6)

# %% [markdown]
# 데이터 시각화를 위해 `matplotlib.pyplot`를 `plt`라는 별칭으로 불러온다.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **데이터 저장소 디렉토리**

# %% [markdown]
# 코드에 사용되는 [데이터 저장소의 기본 디렉토리](https://github.com/codingalzi/DataSci/tree/master/data)를 지정한다.

# %%
data_url = 'https://raw.githubusercontent.com/codingalzi/DataSci/refs/heads/master/data/'

# %% [markdown]
# ## 타이타닉 데이터셋

# %% [markdown]
# 타이타닉호의 승객에 대한 정보와 생존 여부를 담은 데이터셋을 불러온다.

# %%
titanic = pd.read_csv(data_url+"titanic.csv")

# %% [markdown]
# 각 생존자별로 12개의 정보가 포함된다.

# %% [markdown]
# | 특성 | 의미 |
# | :--- | :--- |
# | PassengerId  | 승객 번호 |
# | Survived | 생존 여부. 0 또는 1. 1일 때 생존 |
# | Pclass | 승객 클래스 |
# | Name | 승객 이름 |
# | Sex | 승객의 성 |
# | Age | 승객 나이 |
# | SibSp | 타이타닉에 함께 승선한 형제자매와 배우자의 수 |
# | Parch | 타이타닉에 함께 승선한 자녀와 부모의 수 |
# | Ticket | 티켓 번호 |
# | Fare | 티켓 요금(영국 파운드화) |
# | Cabin | 객실 번호 |
# | Embarked | 승객이 타이타닉호에 승선한 항구 |
# | | C=Cherbourg, Q=Queenstown, S=Southampton |

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# **인덱스 변경**

# %% [markdown]
# 먼저 `PassengerId` 특성을 인덱스로 지정한다.

# %%
titanic = titanic.set_index("PassengerId")

# %%
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %% [markdown]
# **데이터분석 목표**

# %% [markdown]
# 승객의 생존에 영향을 많이 끼친 특성을 파악한다.

# %% [markdown]
# ### 결측치 처리

# %% [markdown]
# **결측치 확인**

# %% [markdown]
# 데이터셋의 크기인 891보다 적은 수의 `non-null` 값을 갖는 특성에 결측치가 존재한다.
# 데이터프레임의 `info()` 메서드로 확인하면 `Age`, `Cabin`, `Embarked` 특성에
# 아래 표에 언급된 만큼의 결측치가 포함된다.
#
# | 특성 | 결측치 수 |
# | :--- | :---: |
# | `Age` | 177 |
# | `Cabin` | 687 |
# | `Embarked` | 2 |

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# - `Cabin` 특성 결측치:
#     - 약 77%가 결측치다.
#     - 이처럼 결측치의 비율이 너무 큰 경우엔 해당 특성을 무시하는 게 좋다.
# - `Age` 특성 결측치
#     - 보통 평균값 또는 중앙값으로 대체한다.
#     - 경우에 따라 성별 또는 나이대별 나이의 평균값, 중앙값 등으로 대체하기도 한다.
#     - 어떤 방식이 데이터분석의 목적에 보다 적합한가는 미리 알 수 없다.
# - `Embarked` 특성 결측치
#     - 범주형 특성의 결측치는 일반적으로 최빈값으로 대체한다.
#     - 게다가 결측치가 2개밖에 없기에 최빈값으로 대체해도 데이터분석에 별 영향을 주지 않을 것이다.

# %% [markdown]
# **`Embarked` 특성 결측치 처리**

# %% [markdown]
# `Embarked` 특성의 결측치를 모두 해당 특성의 최빈값으로 대체한다.

# %%
embarked_mode =(titanic['Embarked'].mode().values)[0]
embarked_mode
# Out:
# 'S'

# %%
titanic['Embarked'] = titanic['Embarked'].fillna(embarked_mode)

# %% [markdown]
# `Embarked` 특성의 결측치는 이제 더 이상 없다.

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# **`Age` 특성 결측치 처리 방법 1: 특성 중앙값 활용**

# %% [markdown]
# `Age` 특성의 결측치를 다양한 방식으로 채운다.
# 따라서 `titanic` 데이터셋의  원본을 그대로 두고 복제해서 사용한다.

# %%
titanic_median = titanic.copy()

# %% [markdown]
# `Age` 특성의 결측치를 모두 해당 특성의 중앙값으로 대체한다.

# %%
age_median =titanic_median['Age'].median()
age_median
# Out:
# 28.000000

# %%
titanic_median['Age'] = titanic_median['Age'].fillna(age_median)

# %%
titanic_median.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       891 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# **`Age` 특성 결측치 처리 방법 2: 성(Sex)별 중앙값 활용**

# %% [markdown]
# - 방식 1: 부울 인덱싱 활용

# %% [markdown]
# 먼저 타이타닉 데이터셋을 복제한다.

# %%
titanic_sex_median = titanic.copy()

# %% [markdown]
# 여성과 남성의 중위연령을 확인한다.

# %%
f_mask = titanic_sex_median["Sex"]=="female"
f_age_median = titanic_sex_median.loc[f_mask, "Age"].median()
print("여성 평균연령:", f_age_median)
# Out:
# 여성 평균연령: 27.0

# %%
m_mask = titanic_sex_median["Sex"]=="male"
m_age_median = titanic_sex_median.loc[m_mask, "Age"].median()
print("남성 평균연령:", m_age_median)
# Out:
# 남성 평균연령: 29.0

# %% [markdown]
# 부울 인덱싱으로 남녀별로 각각의 중위값으로 결측치를 대체한다.

# %%
titanic_sex_median.loc[f_mask, 'Age'] = titanic_sex_median.loc[f_mask, 'Age'].fillna(f_age_median)
titanic_sex_median.loc[m_mask, 'Age'] = titanic_sex_median.loc[m_mask, 'Age'].fillna(m_age_median)

# %% [markdown]
# `Cabin` 특성을 제외한 모든 결측치가 사라졌음을 확인한다.

# %%
titanic_sex_median.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       891 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# - 방식 2: `groupby()` 활용

# %% [markdown]
# 먼저 타이타닉 데이터셋을 복제한다.

# %%
titanic_sex_median = titanic.copy()

# %% [markdown]
# 여성과 남성의 중위연령을 확인한다.

# %%
titanic_sex_median.groupby('Sex')['Age'].median()
# Out:
# Sex
# female    27.0
# male      29.0
# Name: Age, dtype: float64

# %% [markdown]
# 아래 코드는 성별에 따라 결측치를 각각의 중위값으로 대체한다.

# %%
titanic_sex_median_age = titanic_sex_median.groupby('Sex')['Age'].apply(lambda y:y.fillna(y.median()))
titanic_sex_median_age
# Out:
# Sex     PassengerId
# female  2              38.0
#         3              26.0
#         4              35.0
#         9              27.0
#         10             14.0
#                        ...
# male    884            28.0
#         885            25.0
#         887            27.0
#         890            26.0
#         891            32.0
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# 다중인덱스의 레벨 1에 위치한 `PassensgerId` 기준으로 오름차순으로 정렬한다.

# %%
titanic_sex_median_age = titanic_sex_median_age.sort_index(level=1)
titanic_sex_median_age
# Out:
# Sex     PassengerId
# male    1              22.0
# female  2              38.0
#         3              26.0
#         4              35.0
# male    5              35.0
#                        ...
#         887            27.0
# female  888            19.0
#         889            27.0
# male    890            26.0
#         891            32.0
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# `Age` 특성의 값으로 지정하면 나이의 모든 결측치가 성별 중위연령으로 대체된다.

# %%
titanic_sex_median.loc[:, 'Age'] = titanic_sex_median_age.values

# %% [markdown]
# `Cabin` 특성을 제외한 모든 결측치가 사라졌음을 확인한다.

# %%
titanic_sex_median.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       891 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# ### 생존률 확인

# %% [markdown]
# `Survived` 특성의 통계 정보를 확인한다.

# %%
titanic_sex_median['Survived'].describe()
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Survived, dtype: float64

# %% [markdown]
# 평균값이 약 0.38인데 이는 생존률이 약 38%임을 의미한다.
# 이유는 `Survived` 특성에 사용된 값이 0 또는 1이기에
# 해당 특성의 모든 값을 더한 값이 바로 생존자의 수와 같기 때문이다.
# 아래 코드는 총 891명 중에 생존자가 342명에 불과함을 확인해준다.

# %%
titanic["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# 따라서 생존율은 다음과 같이 약 38%다.

# %%
342/891
# Out:
# 0.383838

# %% [markdown]
# 그런데 영화 타이타닉(1997년 개봉)을 보면 성, 나이, 신분, 가족 유무 등에 따라 생존률이 많이 다를 것으로 기대된다.
# 여기서는 성과 나이대에 따라 생존률이 많아 달라짐을 보인다.

# %% [markdown]
# **성별 생존률**

# %% [markdown]
# 성별 생존률은 `groupby()` 메서드로 바로 확인된다.
# 바로 위에서 설명한 대로 `Survived`의 그룹별 평균값이 그룹별 생존률이다.
#
# 여성의 생존률은 74%를 넘는 반면에 남성의 생존률은 채 20%가 되지 않는다.

# %%
titanic_sex_median[["Sex", "Survived"]].groupby(['Sex']).mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %% [markdown]
# **나이대별 생존률**

# %% [markdown]
# 10년 기준으로 나이대를 지정하여 `Age_Bucket` 특성으로 추가한다.
# 아래 코드에 사용된 `astype('i8')` 또는 `astype('int64')`는 해당 특성에 포함된
# 값들의 자료형인 `dtype`을 정수형으로 지정한다.

# %%
titanic_sex_median["Age_Bucket"] = (titanic_sex_median["Age"] // 10 * 10).astype('i8')
titanic_sex_median
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female  27.0
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
#              Age_Bucket
# PassengerId
# 1                    20
# 2                    30
# 3                    20
# 4                    30
# 5                    30
# ...                 ...
# 887                  20
# 888                  10
# 889                  20
# 890                  20
# 891                  30
#
# [891 rows x 12 columns]

# %% [markdown]
# 나이대별 생존률은 다음과 같다.

# %%
titanic_sex_median[["Age_Bucket", "Survived"]].groupby(['Age_Bucket']).mean()
# Out:
#             Survived
# Age_Bucket
# 0           0.612903
# 10          0.401961
# 20          0.324937
# 30          0.437126
# 40          0.382022
# 50          0.416667
# 60          0.315789
# 70          0.000000
# 80          1.000000

# %% [markdown]
# 10살 미만의 생존률이 61%로 가장 높다.
# 구조 과정에서 아기와 아이들의 우선순위가 높았기 때문으로 추정된다.
# 반면에 80대가 100%의 생존률을 보인 반면에 70대의 생존률은 0%인 점이 특이하다.
#
# 이유는 80대보다 70대의 생존률이 높은 게 상식인데 그렇지 않기 때문이다.
# 이런 경우에는 보통 도수가 중요하다.
# 따라서 그룹별 도수를 확인해 본다.

# %%
titanic_sex_median[["Age_Bucket", "Survived"]].groupby(['Age_Bucket']).count()
# Out:
#             Survived
# Age_Bucket
# 0                 62
# 10               102
# 20               397
# 30               167
# 40                89
# 50                48
# 60                19
# 70                 6
# 80                 1

# %% [markdown]
# 80대는 1명 뿐이었고, 그 한 명이 생존하였기에 100%의 생존률이 나왔는데,
# 70대의 6명은 모두 생존하지 못했다.
# 따라서 80대의 생존률이 100%인 것에 대해 큰 의미를 부여할 필요는 없다.

# %% [markdown]
# **성별+나이대별 생존률**

# %% [markdown]
# 영화 타이타닉의 구조 과정에서 어린 아이들 뿐만 아니라 여성, 노약자 등을 우선적으로 구명보트에 태우는 것을 볼 수 있다.
# 이처럼 나이뿐만 아니라 성별도 생존률에 지대한 영향을 끼쳤을 것으로 추정할 수 있으며
# 이를 데이터로 확인해 본다.
#
# 아래 코드는 `Sex`와 `Age_Bucket`을 기준으로 그룹화를 진행한 다음에
# 그룹별로 생존률을 계산한다.
# 그룹화의 기준으로 두 개 이상의 특성을 사용할 수 있으며 그 결과는 어렵지 않게 이해된다.
#
# - 먼저 언급된 `Sex`, 즉 성별로 그룹화 한다.
# - 이후 각각의 그룹에 대해 `Age_Bucket`, 즉 나이대별로 그룹화 한다.

# %%
titanic_sex_median[["Age_Bucket", "Sex", "Survived"]].groupby(['Sex', 'Age_Bucket']).mean()
# Out:
#                    Survived
# Sex    Age_Bucket
# female 0           0.633333
#        10          0.755556
#        20          0.704000
#        30          0.833333
#        40          0.687500
#        50          0.888889
#        60          1.000000
# male   0           0.593750
#        10          0.122807
#        20          0.150735
#        30          0.214953
#        40          0.210526
#        50          0.133333
#        60          0.133333
#        70          0.000000
#        80          1.000000

# %% [markdown]
# 앞서 살펴본 대로 여성의 생존률이 약 74.2%인데
# 여성 50대는 약 89%, 그리고 60대는 100%의 여성 평균 생존률보다 훨씬 높다.
#
# 앞서 언급했듯이 이런 경우엔 도수도 확인해봐야 한다.

# %%
titanic_sex_median[["Age_Bucket", "Sex", "Survived"]].groupby(['Sex', 'Age_Bucket']).count()
# Out:
#                    Survived
# Sex    Age_Bucket
# female 0                 30
#        10                45
#        20               125
#        30                60
#        40                32
#        50                18
#        60                 4
# male   0                 32
#        10                57
#        20               272
#        30               107
#        40                57
#        50                30
#        60                15
#        70                 6
#        80                 1

# %% [markdown]
# 50대 여성은 18명, 60대 여성은 4명으로 무시하기 어렵다.
# 50대 이상의 여성의 생존률이 높은 이유는
# 노약자를 우선적으로 구명보트에 태웠기 때문인 것으로 추정된다.

# %% [markdown]
# 반면에 10살 미만의 여자 아이들의 생존률이 타 여성연령그룹보다 상대적으로 낮으며,
# 10살 미만의 남자 아이들의 생존률은 타 남성연령그룹보다 상대적으로 높다.
# 이에 대한 이유는 명확하지 않다.

# %%
mask = titanic_sex_median['Age'] < 10
titanic_sex_median[mask].groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.633333
# male      0.593750
# Name: Survived, dtype: float64

# %% [markdown]
# 참고로 10살 미만의 평균 생존률은 61.3%다.

# %%
mask = titanic_sex_median['Age'] < 10
titanic_sex_median.loc[mask, 'Survived'].mean()
# Out:
# np.float64(0.6129032258064516)

# %% [markdown]
# **가족의 생존률**

# %% [markdown]
# `SisSp`는 형제자매와 배우자의 수를, `Parch`는 부모와 자식의 수를 가리킨다.
# 따라서 함께 타이타닉호에 탑승한 가족의 수는 두 특성의 합으로 계산된다.
# 아래 코드는 이를 새로운 특성으로 추가한다.

# %%
titanic_sex_median["RelativesOnboard"] = titanic_sex_median["SibSp"] + titanic_sex_median["Parch"]

# %% [markdown]
# 함께 탑승한 가족의 수에 따른 승객의 수는 다음과 같다.
# 가족이 0명, 즉 혼자 타이타닉호에 탑승한 승객이 537명으로 가장 많다.
# 그 다음으로 1명 또는 2명의 가족과 함께 탑승한 승객들이 많다.
# 최대 11명의 대가족으로 구성된 승객도 7명이나 된다.

# %%
titanic_sex_median["RelativesOnboard"].value_counts().sort_index()
# Out:
# RelativesOnboard
# 0     537
# 1     161
# 2     102
# 3      29
# 4      15
# 5      22
# 6      12
# 7       6
# 10      7
# Name: count, dtype: int64

# %% [markdown]
# 함께 탑승한 가족수를 기준으로 그룹별 생존률을 확인하면 함께 탑승한 가족이 1명에서 3명일 때
# 승객의 생존률이 압도적으로 높다.
# 이또한 아무래도 어린 아이들과 노약자를 우선적으로 구조한 데에서 이유를 찾을 수 있을 것이다.

# %%
titanic_sex_median[["RelativesOnboard", "Survived"]].groupby(['RelativesOnboard']).mean()
# Out:
#                   Survived
# RelativesOnboard
# 0                 0.303538
# 1                 0.552795
# 2                 0.578431
# 3                 0.724138
# 4                 0.200000
# 5                 0.136364
# 6                 0.333333
# 7                 0.000000
# 10                0.000000

# %% [markdown]
# 성별로 구분해서 보면 남성의 경우도 2명에서 4명으로 구성된 가족의 구성원인 경우
# 남성 평균의 생존률 18.8% 보다 훨씬 높다.

# %%
titanic_sex_median[["Sex", "RelativesOnboard", "Survived"]].groupby(['Sex', 'RelativesOnboard']).mean()
# Out:
#                          Survived
# Sex    RelativesOnboard
# female 0                 0.785714
#        1                 0.816092
#        2                 0.775510
#        3                 0.842105
#        4                 0.250000
#        5                 0.375000
#        6                 0.375000
#        7                 0.000000
#        10                0.000000
# male   0                 0.155718
#        1                 0.243243
#        2                 0.396226
#        3                 0.500000
#        4                 0.000000
#        5                 0.000000
#        6                 0.250000
#        7                 0.000000
#        10                0.000000

# %% [markdown]
# ## 연습문제

# %% [markdown]
# **문제 1**

# %% [markdown]
# (1) `Cabin` 특성에 결측치가 많다.
# 객실 정보가 있는 경우와 그렇지 않은 경우의 생존률을 확인하라.
#
# 힌트: `pd.isna()`, `pd.notna()` 함수 또는 `pd.DataFrame.isna()`, `pd.DataFrame.notna()` 메서드 활용

# %%
# 코드를 작성한다.
# 필요하면 코드셀 또는 텍스트셀을 추가할 수 있습니다.

# %% [markdown]
# (2) 여성의 생존률이 평균적으로 훨씬 높다. 객실 정보가 있는 경우 성별 생존률을 확인하라.

# %%
# 코드를 작성한다.
# 필요하면 코드셀 또는 텍스트셀을 추가할 수 있습니다.

# %% [markdown]
# (3) 객실 정보가 있는 경우 객실의 첫문자를 `C_Initial` 특성으로 추가하라.
# 또한 첫문자별 도수를 확인하라.
#
# 힌트: `pd.Series.map()` 메서드 활용

# %%
# 코드를 작성한다.
# 필요하면 코드셀 또는 텍스트셀을 추가할 수 있습니다.

# %% [markdown]
# (4) 객실의 첫문자별로 객실의 요금의 평균값을 확인하라.

# %%
# 코드를 작성한다.
# 필요하면 코드셀 또는 텍스트셀을 추가할 수 있습니다.

# %% [markdown]
# (5) 객실의 첫문자별 생존률을 확인하라.

# %%
# 코드를 작성한다.
# 필요하면 코드셀 또는 텍스트셀을 추가할 수 있습니다.

# %% [markdown]
# (6) 객실의 첫문자별 남녀 생존률을 확인하라.

# %%
# 코드를 작성한다.
# 필요하면 코드셀 또는 텍스트셀을 추가할 수 있습니다.

# %% [markdown]
# **문제 2**

# %% [markdown]
# 타이타닉호에 탑승했던 891명의 승객에서 1명을 무작위로 선택했을 때의 생존여부를 가리키는 확률 변수를 X라 하자.
# 확률 변수 X의 확률 분포는 다음과 같다.
# 단, 0과 1은 각각 사망과 생존을 가리킨다.
#
# | X | 0 | 1 |
# | :---: | :---: | :---: |
# | 확률 | 0.62 | 0.38 |

# %% [markdown]
# 이유는 다음과 같이 타이타닉 승객의 생존률이 0.38이기 때문이다.

# %%
titanic_sex_median['Survived'].mean()
# Out:
# np.float64(0.3838383838383838)

# %% [markdown]
# (1) 남자 승객에서 1명을 무작위로 선택했을 때의 생존여부를 가리키는 확률 변수를 X라 하자.
# 확률 변수 X의 확률 분포를 구하라.

# %%
# 코드를 작성한다.
# 필요하면 코드셀 또는 텍스트셀을 추가할 수 있습니다.

# %% [markdown]
# (2) 객실 정보가 없는 여자 승객에서 1명을 무작위로 선택했을 때의 생존여부를 가리키는 확률 변수를 X라 하자.
# 확률 변수 X의 확률 분포를 구하라.

# %%
# 코드를 작성한다.
# 필요하면 코드셀 또는 텍스트셀을 추가할 수 있습니다.

# %% [markdown]
# (3) C로 시작하는 객실 정보가 있는 남자 승객에서 1명을 무작위로 선택했을 때의 생존여부를 가리키는 확률 변수를 X라 하자.
# 확률 변수 X의 확률 분포를 구하라.

# %%
# 코드를 작성한다.
# 필요하면 코드셀 또는 텍스트셀을 추가할 수 있습니다.

# %% [markdown]
# **문제 3**

# %% [markdown]
# 타이타닉 호의 객실의 첫문자를 객실을 구분하는 범주로 사용했을 때 각 범주별 도수를 확인한다.
#
# - `value_counts()` 메서드의 `dropna=False` 키워드 인자: 결측치도 하나의 범주로 취급함.

# %%
c_initial = titanic['C_Initial'].value_counts(dropna=False).sort_index()
c_initial
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'C_Initial'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-a7bd848a0207> in <cell line: 0>()
# ----> 1 c_initial = titanic['C_Initial'].value_counts(dropna=False).sort_index()
#       2 c_initial
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'C_Initial'

# %% [markdown]
# (1) 타이타닉호에 탑승했던 891명의 승객에서 무작위로 선택된 승객이 속하는 객실의 범주를 가리키는 확률 변수를 X라 하자.
# 확률 변수 X의 확률 분포를 구하라.
#
# 힌트: `pd.DataFrame.value_counts()` 메서드의 `dropna=False` 키워드 인자 활용

# %%
# 코드를 작성한다.
# 필요하면 코드셀 또는 텍스트셀을 추가할 수 있습니다.

# %% [markdown]
# (2) 타이타닉호에 탑승했던 여성 승객에서 무작위로 선택된 승객이 속하는 객실의 범주를 가리키는 확률 변수를 X라 하자.
# 확률 변수 X의 확률 분포를 구하라.
#
# 힌트: `pd.crosstab()` 함수의 `dropna=False` 키워드 인자 활용.

# %%
# 코드를 작성한다.
# 필요하면 코드셀 또는 텍스트셀을 추가할 수 있습니다.

# %% [markdown]
# **문제 4**

# %% [markdown]
# `Name` 특성만을 이용하여 다양한 경우에 대한 생존률을 계산하라.
#
# 힌트: 아래 두 사이트의 내용을 참고한다.
#
# - [Titanic using Name only [0.81818]](https://www.kaggle.com/code/cdeotte/titanic-using-name-only-0-81818)
# - [Notes of Titanic on Kaggle](https://typewind.github.io/2017/07/25/titanic/)

# %%
# 코드를 작성한다.
# 필요하면 코드셀 또는 텍스트셀을 추가할 수 있습니다.

#호칭별 생존률 분석

#이름에서 호칭을 추출.
titanic['Title'] = titanic['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
titanic['Title']

#호칭별 평균 생존률 계산
#여성 또는 어린이, 고위층일수록 생존률이 높고, 성인 남성은 생존률이 낮습니다.
#countess, Lady, Sir에 호칭을 가진 귀촉 계층들은 모두생존하였다. 이들 그룹은 매우 적은 수의 샘플만 포함할 가능성이 높고, 귀족적 지위나 높은 계층일수록 구조 우선순위가 높았을 수 있다.
titanic_title_survive = titanic[['Title','Survived']].groupby(['Title']).mean()
titanic_title_survive

#각 호칭의 도수 확인
#Mr,Miss,Mrs,Master는 각각 40명 이상이고 해당 그룹의 생존률은 통계적으로 유의미하다.
#표본 수가 적은 그룹은 생존률이 0.0이나 1.0처럼 극단적인 경우가 많다.
titanic['Title'].value_counts()

#샘플 수가 너무 적은 호칭들을 새로운 범주인 'Rare'로 그룹화한다.
rare_titles = ['Dr','Rev','Col','Major','Capt','Don','Lady','Countess','Jonkheer','Sir','Mme','Mlle','Ms']
titanic['Title'] = titanic['Title'].replace(rare_titles, 'Rare')

#rare를 포함해서 호칭별 생존률 계산.
#여성은 구조 시 우선순위가 높았던 것으로 보이며, 높은 생존률을 보인다.
#어린 남성도 꽤 높은 생존률을 보였으며, 이는 구조 시 어린이를 우선적으로 구했기 때문일 가능성이 크다.
#성인 남성은 생존률이 낮은 편으로, 구조에서 우선순위가 낮았기 때문에 생존률이 적다.
#희귀 직함들은 표본이 적어서 결과의 신뢰도가 떨어질 수 있지만, 생존률은 중간 정도이다.
titanic_title_survive = titanic[['Title','Survived']].groupby(['Title']).mean()
titanic_title_survive

#가족 단위 생존률 분석

# 'Surname' 컬럼을 만들기 위해 'Name' 컬럼에서 성을 추출 -> 이름에서 ','기준으로 앞부분만 추출
titanic['Surname'] = titanic['Name'].str.split(',').str[0]

# 같은 성씨를 가진 승객들이 두 명 이상일 때만 '가족'으로 간주
family_groups = titanic.groupby('Surname').filter(lambda x: len(x) > 1)

# 각 가족 단위로 생존률을 계산
family_survival_rate = family_groups.groupby('Surname')['Survived'].mean().reset_index()
print(family_survival_rate)

#호칭 기반으로 성별/나이 그룹 재분류
def refine_gender(title):
    if title == 'Master':
        return 'Child'
    elif title in ['Mr']:
        return 'Male'
    elif title in ['Miss', 'Mrs']:
        return 'Female'
    else:
        return 'Other'

# 성별 분류
titanic['GenderGroup'] = titanic['Title'].apply(refine_gender)

# 그룹별 인원 수
gender_count = family_groups.groupby(['Surname', 'GenderGroup']).size().reset_index(name='Count')

# 그룹별 생존률
gender_survival = family_groups.groupby(['Surname', 'GenderGroup'])['Survived'].mean().reset_index(name='SurvivalRate')

# 병합
family_gender_summary = pd.merge(gender_count, gender_survival, on=['Surname', 'GenderGroup'])

# 결과 보기
# 상위 20개에서는 주로 여성이나 어린이의 비율이 높고 전부 생존한 경우를 보여준다.
# 하위 20개에서는 남성에 비율이 많고 전부 생존하지 못한 경우를 보여준다.
# 즉 성별이나 나이가 생존률에 영향을 미쳤을 가능성이있다.
family_gender_summary = family_gender_summary.sort_values(by='SurvivalRate', ascending=False)
print(family_gender_summary.head(20))

family_gender_summary = family_gender_summary.sort_values(by='SurvivalRate', ascending=True)
print(family_gender_summary.head(20))
# Out:
#       Surname  Survived
# 0      Abbott  0.500000
# 1     Abelson  0.500000
# 2         Ali  0.000000
# 3       Allen  0.500000
# 4     Allison  0.333333
# ..        ...       ...
# 128     White  0.000000
# 129      Wick  1.000000
# 130  Williams  0.250000
# 131   Yasbeck  0.500000
# 132    Zabour  0.000000
#
# [133 rows x 2 columns]
#       Surname GenderGroup  Count  SurvivalRate
# 0      Abbott      Female      1           1.0
# 2     Abelson      Female      1           1.0
# 7     Allison       Child      1           1.0
# 5       Allen      Female      1           1.0
# 28     Becker       Child      1           1.0
# 24     Baxter      Female      1           1.0
# 20  Backstrom      Female      1           1.0
# 22    Baclini      Female      4           1.0
# 17    Asplund      Female      2           1.0
# 12    Andrews      Female      1           1.0
# 33     Bishop        Male      1           1.0
# 32     Bishop      Female      1           1.0
# 31   Beckwith        Male      1           1.0
# 30   Beckwith      Female      1           1.0
# 29     Becker      Female      1           1.0
# 26      Beane      Female      1           1.0
# 27      Beane        Male      1           1.0
# 39      Brown      Female      3           1.0
# 89     Graham      Female      2           1.0
# 99     Harper        Male      1           1.0
#          Surname GenderGroup  Count  SurvivalRate
# 74          Ford        Male      1           0.0
# 76       Fortune        Male      2           0.0
# 71         Elias        Male      3           0.0
# 73          Ford      Female      3           0.0
# 100       Harper       Other      1           0.0
# 56       Collyer        Male      1           0.0
# 91    Gustafsson        Male      4           0.0
# 92       Hagland        Male      2           0.0
# 104         Hart        Male      2           0.0
# 80      Futrelle        Male      1           0.0
# 86       Goodwin       Child      3           0.0
# 87       Goodwin      Female      2           0.0
# 90        Graham        Male      1           0.0
# 94   Hakkarainen        Male      1           0.0
# 153       Morley        Male      2           0.0
# 152        Moran        Male      2           0.0
# 161     Navratil        Male      1           0.0
# 159       Nasser        Male      1           0.0
# 163       Newell        Male      1           0.0
# 167      O'Brien        Male      2           0.0
#           Surname GenderGroup_Male  SurvivalRate_Male GenderGroup_Female  \
# 0          Abbott             Male                0.0             Female
# 1         Abelson             Male                0.0             Female
# 2           Allen             Male                0.0             Female
# 3       Andersson             Male                0.5             Female
# 4         Andrews             Male                0.0             Female
# ..            ...              ...                ...                ...
# 68       Van Impe             Male                0.0             Female
# 69  Vander Planke             Male                0.0             Female
# 70         Webber             Male                0.0             Female
# 71           West             Male                0.0             Female
# 72        Yasbeck             Male                0.0             Female
#
#     SurvivalRate_Female
# 0              1.000000
# 1              1.000000
# 2              1.000000
# 3              0.166667
# 4              1.000000
# ..                  ...
# 68             0.000000
# 69             0.000000
# 70             1.000000
# 71             1.000000
# 72             1.000000
#
# [73 rows x 5 columns]
